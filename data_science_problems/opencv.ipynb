# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('my_picture.jpg')

# %%
plt.figure(figsize=(10, 15))
plt.imshow(img)

# %%
kernel = np.array([[1, 2, 1],[2, 4, 2], [1, 2, 1]])/16
dst = cv2.filter2D(img, -1, kernel)
plt.figure(figsize=(10, 15))
plt.imshow(dst)

# %%
kernel1 = np.array([1, 2, 1])/4
kernel2 = np.array([1, 2, 1])/4
dst = cv2.filter2D(img, -1, kernel1)
dst = cv2.filter2D(dst, -1, kernel2)
plt.figure(figsize=(10, 15))
plt.imshow(dst)

# %%
krug = cv2.imread('krug.png')
#krug = cv2.cvtColor(krug, cv2.COLOR_BGR2GRAY)

# %%
vals = krug.mean(axis=2).flatten()
plt.hist(vals)
# Out:
# (array([3.7804e+04, 2.7000e+01, 2.2000e+01, 1.8000e+01, 1.8000e+01,
#         1.7000e+01, 2.2000e+01, 2.0000e+01, 3.3000e+01, 4.8680e+03]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)
